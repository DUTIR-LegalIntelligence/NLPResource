# %%
with open('vec.txt','r',encoding='utf-8') as file:
                
    for line in file:
        line = line.strip()
        
        if len(line) <= 1:
            
        
            continue
        tokens = line.split()
        print(len(tokens))
        if len(tokens) <= 3:
            continue
#         if len(tokens[0])>1:
#             self.words_longer_than_one.add(tokens[0])
# Out:
# 2
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# ...
